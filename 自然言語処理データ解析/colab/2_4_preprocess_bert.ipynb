# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/project_root/
# Out:
# /content/drive/MyDrive/project_root

# %%
# ここで，.pyプログラムと configs/ が含まれていればよい．
# %ls ./src
# Out:
# configs/            p1_0_sample_infer.py  p4_0_compute_cost.py         result/
# data/               p1_0_sample_train.py  p4_0_output_infer_result.py
# __init__.py         p2_4_bert_infer.py    p4_0_output_train_result.py
# p1_0_preprocess.py  p2_4_bert_train.py    __pycache__/

# %%
# ここで，NN_config.json, preprocess_default_config.json, preprocess_sample_config.jsonなどのコンフィグが含まれていればよい．

# %ls ./src/configs/2_4
# Out:
# bert_config.json        preprocess_bert_config.json
# no_cv_bert_config.json  preprocess_no_cv_bert_config.json

# %%
# datasetsは3.6.0推奨．4.0.0以降は動作しない．これらは，1_0_preprocess.pyを動かすために必要．
# !pip install datasets==3.6.0 sudachipy pandas numpy pyarrow sudachidict_core
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 11.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 63.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.2/72.2 MB 10.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: datasets
#     Found existing installation: datasets 4.0.0
#     Uninstalling datasets-4.0.0:
#       Successfully uninstalled datasets-4.0.0
# ...

# %%
# 左のバーのファイルから/content/src/1_0_preprocess.pyと/content/configs/<自分のディレクトリ>/<任意のconfigファイル>.jsonをアップロードして動作
# 今回はsrcをパッケージとして扱うので-mを使う
# 初回動作時は，Do you wish to run the custom code? [y/N]と聞かれるため，そのすぐ右をクリックしてyを入力
# !python -m src.p1_0_preprocess --config ./src/configs/2_4/preprocess_bert_config.json
# Out:
# README.md: 4.44kB [00:00, 2.06MB/s]
# livedoor-news-corpus.py: 5.17kB [00:00, 15.5MB/s]
# The repository for shunk031/livedoor-news-corpus contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/shunk031/livedoor-news-corpus.
# You can avoid this prompt in future by passing the argument `trust_remote_code=True`.
#
# Do you wish to run the custom code? [y/N] y
# ...
# Generating train split: 5894 examples [00:02, 2640.27 examples/s]
# Generating validation split: 737 examples [00:00, 2666.21 examples/s]
# Generating test split: 736 examples [00:00, 2352.48 examples/s]
# Start preprocessing...
# config path: ./src/configs/2_4/preprocess_bert_config.json
# ...

# %%
# ランタイムをGPUに変更すること．
# CPUでやると時間がかかる
# サンプルに時間をかけたくないのでEpoch数は少ない．本番は十分にEpoch数を確保すること
# !python -m src.p2_4_bert_train --config ./src/configs/2_4/bert_config.json
# Out:
# 2025-11-16 20:38:01.853058: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763325481.906122    4053 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763325481.916486    4053 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763325481.941492    4053 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %% [markdown]
# Epoch数を十分に確保しても過学習する．
# より詳細な結果はresultディレクトリに出力している
# モデルとパラメータが適当なので結果は良くないが，少なくともコードの参考にはなるはず．
# 過学習をしないように工夫してみてください．

# %%
# こっちは，クロスバリデーションをしないため，早い
# Epoch数が少ないので超早い
# configs/1_0にno_cvのconfigを入れてから実行
# 初回動作時は，Do you wish to run the custom code? [y/N]と聞かれるため，そのすぐ右をクリックしてyを入力
# !python -m src.p2_4_preprocess --config ./src/configs/2_4/preprocess_no_cv_bert_config.json
# !echo "start 1_0_sample.py"
# !python -m src.p2_4_bert_train --config ./src/configs/2_4/no_cv_bert_config.json

# %%
# !python -m src.p2_4_bert_infer --ts-dir ./src/result/2_4_preprocess_bert/fold_1/reports/2025-11-16_10-28-06 --data ./src/data/2_4_preprocessed_bert/cv_k5/test.parquet
# Out:
# 2025-11-16 20:35:20.183371: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763325320.215840    3283 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763325320.227623    3283 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763325320.251423    3283 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
