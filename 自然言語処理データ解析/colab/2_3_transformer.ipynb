# %%
# 必要モジュール　サンプルよりtorchとmatplotlibを追加（自環境になかったため）
# 
# !pip install datasets==3.6.0 sudachipy pandas numpy pyarrow sudachidict_core torch matplotlib scikit-learn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 53.0 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.7/35.7 MB 73.0 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [scikit-learn] [scikit-learn]
# ...

# %%
import os
# リポジトリのrootにワーキングディレクトリを移動（環境に合わせる）
os.chdir('/home/tau/document-classification')
#os.chdir('/path/to/repository/root/document-classification')
#os.chdir('../') # colab -> document-classification

# %%
# !python -m src.p1_0_preprocess --config ./src/configs/2_3/preprocess_transformer_config.json
# Out:
# ...
# Generating test split: 100%|█████████| 736/736 [00:00<00:00, 3930.40 examples/s]
# Start preprocessing...
# config path: ./src/configs/2_3/preprocess_transformer_config.json
# ...

# %%
# !python -m src.p2_3_transformer_train --config ./src/configs/2_3/transformer_config.json
# Out:
# Using CV directory: cv_k5
# Running in Cross-Validation mode.
# Using common test set: src/data/2_3_transformer_preprocessed/cv_k5/test.parquet
#
# === fold_1 ===
# /home/tau/doc-classify/lib/python3.13/site-packages/torch/nn/modules/transformer.py:392: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(
# Epoch 1/20
# Training:  82%|█████████████████████████▎     | 271/332 [00:12<00:02, 22.48it/s]
