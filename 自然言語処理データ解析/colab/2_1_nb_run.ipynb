# %%
# !python -m src.p1_0_preprocess --config ./src/configs/1_0/preprocess_sample_config.json
# 前処理の結果を確認
# Out:
# Start preprocessing...
# config path: ./src/configs/1_0/preprocess_sample_config.json
# Saved: {'folds': {'fold_1': {'train': 'src\\data\\1_0_preprocessed\\cv_k5\\fold_1\\train.parquet', 'val': 'src\\data\\1_0_preprocessed\\cv_k5\\fold_1\\val.parquet'}, 'fold_2': {'train': 'src\\data\\1_0_preprocessed\\cv_k5\\fold_2\\train.parquet', 'val': 'src\\data\\1_0_preprocessed\\cv_k5\\fold_2\\val.parquet'}, 'fold_3': {'train': 'src\\data\\1_0_preprocessed\\cv_k5\\fold_3\\train.parquet', 'val': 'src\\data\\1_0_preprocessed\\cv_k5\\fold_3\\val.parquet'}, 'fold_4': {'train': 'src\\data\\1_0_preprocessed\\cv_k5\\fold_4\\train.parquet', 'val': 'src\\data\\1_0_preprocessed\\cv_k5\\fold_4\\val.parquet'}, 'fold_5': {'train': 'src\\data\\1_0_preprocessed\\cv_k5\\fold_5\\train.parquet', 'val': 'src\\data\\1_0_preprocessed\\cv_k5\\fold_5\\val.parquet'}}, 'test': 'src\\data\\1_0_preprocessed\\cv_k5\\test.parquet'}
#
# === Category counts for fold_1 ===
#    train  validation  test  total
# ...

# %%
# ナイーブベイズで学習
# !python -m src.p2_1_nb_train --config ./src/configs/2_1/p2_nb_train_config.json
#p4_0_compute_cost.pyを使って計算コストを計算するとき、Naive BayesだとPyTorchを使った計算でcost計算ができない
#NBは十分高速なので学習コストは無視する
# Out:
# [INFO] Config snapshot saved to src\result\1_0_preprocess_sample\2025-11-18_18-27-52\2025-11-18_18-27-56\config\used_config.json
# [train] accuracy=0.9136  macro_f1=0.9024  micro_f1=0.9136
# [val] accuracy=0.8791  macro_f1=0.8591  micro_f1=0.8791
# [INFO] Model saved to src\result\1_0_preprocess_sample\2025-11-18_18-27-52\2025-11-18_18-27-56\models\model.pt
# [INFO] (compat) Duplicated to src\result\1_0_preprocess_sample\2025-11-18_18-27-52\2025-11-18_18-27-56\models\model_state_dict.pt
# [INFO] Artifact saved under models/: src\result\1_0_preprocess_sample\2025-11-18_18-27-52\2025-11-18_18-27-56\models\nb_model.pkl
# [INFO] Artifact saved under models/: src\result\1_0_preprocess_sample\2025-11-18_18-27-52\2025-11-18_18-27-56\models\tfidf.pkl
# ...
#   Naive Bayes トレーニング完了
# ...
# train acc = 0.9136
# val   acc = 0.8791
# Saved to src\result\1_0_preprocess_sample\2025-11-18_18-27-52
# [WARN] test: 入力が無いためスキップします。
# [WARN] training_cost が提供されていないため、学習コスト保存をスキップします。
# ...

# %%
# !python -m src.p2_1_nb_infer --config ./src/configs/2_1/no_cv_NB_config.json --model_dir ./src/result/1_0_preprocess_sample/2025-11-18_18-27-52/model --input ./src/data/1_0_no_cv_preprocessed/test.parquet
#p4_0_compute_cost.pyを使って計算コストを計算するとき、Naive BayesだとPyTorchを使った計算でcost計算ができない
# Out:
# [INFO] Config snapshot saved to src\result\1_0_preprocess_sample\infer_2025-11-18_18-28-13\2025-11-18_18-28-13\config\used_config.json
# [INFO] Model saved to src\result\1_0_preprocess_sample\infer_2025-11-18_18-28-13\2025-11-18_18-28-13\models\model.pt
# [INFO] (compat) Duplicated to src\result\1_0_preprocess_sample\infer_2025-11-18_18-28-13\2025-11-18_18-28-13\models\model_state_dict.pt
# [INFO] Artifact saved under models/: src\result\1_0_preprocess_sample\infer_2025-11-18_18-28-13\2025-11-18_18-28-13\models\nb_model.pkl
# [INFO] Artifact saved under models/: src\result\1_0_preprocess_sample\infer_2025-11-18_18-28-13\2025-11-18_18-28-13\models\tfidf.pkl
# ...
#   Naive Bayes 推論完了
# accuracy = 0.8863
# Saved to src\result\1_0_preprocess_sample\infer_2025-11-18_18-28-13
# [WARN] train: 入力が無いためスキップします。
# [WARN] val: 入力が無いためスキップします。
# [WARN] test: 入力が無いためスキップします。
# [WARN] training_cost が提供されていないため、学習コスト保存をスキップします。
# [WARN] history が提供されていないため、学習曲線の保存をスキップします。
